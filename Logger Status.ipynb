# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches
import mpld3

# %matplotlib inline

# %%
path = 'C:/Users/Julia/work/Loggernet/'
loggers = ['CR6', 'CR5000', 'CR1000', 'CL06_CR1000', 'Wash_Strm_CR200', 'Upper WS CR200']
places = zip([0]*len(loggers), range(0, 5*len(loggers),5))

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.set_xlim(-5,50)
ax.set_ylim(-5,len(loggers)*5)
mpld3.plugins.clear(fig)
#loggers
for logger, place in zip(loggers, places):
    fs = os.listdir(path)
    i = 0
    for f in fs:
        if logger in f:
            i = max(i, os.path.getmtime(path+f))
    t = time.time() - i
    hover_text = time.ctime(i)
    if 0 < t< 60*60:
        c = "#9ACD32"
    elif t < 60*60*24:
        c = "#FFFF2F"
    elif t < 60*60*24*7:
        c = "#FF7B24"
    else:
        c = "#CF1F0F"
    rect = matplotlib.patches.Rectangle(place, width=3, height=3, facecolor=c)
    ax.add_patch(rect)
    line = matplotlib.patches.Arrow(place[0]+3, place[1]+2, 15, 12-place[1], width=1, ec='w', fc='k')
    h=ax.add_patch(line)
    
    ax.annotate(logger, xy=(place[0],place[1]+3.5), size=12)
    tooltip = mpld3.plugins.PointLabelTooltip(h, labels=[hover_text])
    mpld3.plugins.connect(fig, tooltip)
    
ax.set_axis_off()

ax.annotate('Lidar Lab computer', xy=(19,20), size=12)
rect = matplotlib.patches.Rectangle((19,9), width=8, height=10, facecolor='#FFFFFF')
ax.add_patch(rect)
line = matplotlib.patches.Arrow(28,14, 10, 0, width=1, ec='w', fc='k')
ax.add_patch(line)

# make a cloud
cloud_dims = zip([[40,13], [42,13.5], [44,14], [46,13]], [1.5, 2, 2.5, 1.5])
ax.annotate('CEE Cloud', xy=(40,18), size=12)
for place, rad in cloud_dims:
    circ = matplotlib.patches.Circle(place, radius=rad, fc='#3333EE', ec='none')
    ax.add_patch(circ)
ax.figure.canvas.draw()

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el24282215813849273109529"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el24282215813849273109529", {"axes": [{"xlim": [-5.0, 50.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "CR6", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 3.5], "rotation": -0.0, "id": "el2428231501104"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "CR5000", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 8.5], "rotation": -0.0, "id": "el2428231498752"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "CR1000", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 13.5], "rotation": -0.0, "id": "el2428192243248"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "CL06_CR1000", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 18.5], "rotation": -0.0, "id": "el2428216908128"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Wash_Strm_CR200", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 23.5], "rotation": -0.0, "id": "el2428218901864"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Upper WS CR200", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.0, 28.5], "rotation": -0.0, "id": "el2428224483480"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Lidar Lab computer", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [19, 20], "rotation": -0.0, "id": "el2428213720088"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "CEE Cloud", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [40, 18], "rotation": -0.0, "id": "el2428239965352"}], "zoomable": true, "images": [], "xdomain": [-5.0, 50.0], "ylim": [-5.0, 30.0], "paths": [{"edgecolor": "#000000", "facecolor": "#FF7B24", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el2428211697280"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el2428211695712"}, {"edgecolor": "#000000", "facecolor": "#9ACD32", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el2428210172056"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data03", "id": "el2428210171384"}, {"edgecolor": "#000000", "facecolor": "#9ACD32", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el2428231501664"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data04", "id": "el2428231498192"}, {"edgecolor": "#000000", "facecolor": "#FFFF2F", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el2428231500096"}, {"edgecolor": "#FFFFFF", "facecolor": "#000000", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data05", "id" ...
